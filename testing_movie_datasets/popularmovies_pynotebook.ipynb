# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_json("popularmovies.json")

# %%
df
# Out:
#     page                                            results  total_pages  \
# 0      1  {'adult': False, 'backdrop_path': '/iIvQnZyzgx...        40192
# 1      1  {'adult': False, 'backdrop_path': '/H6j5smdpRq...        40192
# 2      1  {'adult': False, 'backdrop_path': '/ctMserH8g2...        40192
# 3      1  {'adult': False, 'backdrop_path': '/4XM8DUTQb3...        40192
# 4      1  {'adult': False, 'backdrop_path': '/8pjWz2lt29...        40192
# 5      1  {'adult': False, 'backdrop_path': '/iiXliCeykk...        40192
# 6      1  {'adult': False, 'backdrop_path': '/53z2fXEKfn...        40192
# 7      1  {'adult': False, 'backdrop_path': '/c6Splshb8l...        40192
# 8      1  {'adult': False, 'backdrop_path': '/4fLZUr1e65...        40192
# 9      1  {'adult': False, 'backdrop_path': '/35z8hWuzfF...        40192
# 10     1  {'adult': False, 'backdrop_path': '/waBWlJlMpy...        40192
# 11     1  {'adult': False, 'backdrop_path': '/w2nFc2Rsm9...        40192
# ...
